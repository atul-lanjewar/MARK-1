# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('fire1.csv')

# %%
data
# Out:
#         year  month        state   latitude  longitude  firespots
# 0     1999.0    1.0     AMAZONAS  -2.371113 -59.899933        3.0
# 1     1999.0    1.0     MARANHAO  -2.257395 -45.487831       36.0
# 2     1999.0    1.0  MATO GROSSO -12.660633 -55.057989       18.0
# 3     1999.0    1.0         PARA  -2.474820 -48.546967       87.0
# 4     1999.0    1.0     RONDONIA -12.861700 -60.513100        1.0
# ...      ...    ...          ...        ...        ...        ...
# 2099  2019.0   12.0  MATO GROSSO -12.138385 -56.066297      148.0
# 2100  2019.0   12.0         PARA  -2.976727 -50.909316     1280.0
# 2101  2019.0   12.0     RONDONIA -10.809262 -62.890452       42.0
# 2102  2019.0   12.0      RORAIMA   2.856667 -60.431963       27.0
# 2103  2019.0   12.0    TOCANTINS  -6.769381 -48.475667       21.0
#
# [2104 rows x 6 columns]

# %%
x=data.year
y=data.month
z=data.state
v=data.latitude
k=data.longitude
l=data.firespots
plt.plot(l,x)

plt.title('data visualisation')
plt.xlabel('firespots')
plt.ylabel('year')
# Out:
# Text(0, 0.5, 'year')

# %%
plt.plot(l,y)
plt.xlabel('firespots')
plt.ylabel('month')
# Out:
# Text(0, 0.5, 'month')

# %%
plt.plot(l,v)
plt.xlabel('firespots')
plt.ylabel('latitude')
# Out:
# Text(0, 0.5, 'latitude')

# %%
plt.plot(l,k)
plt.xlabel('firespots')
plt.ylabel('longitude')
# Out:
# Text(0, 0.5, 'longitude')
